# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('FlightData6D.tsv',sep='\t',skiprows=11)
df
# Out:
#        Frame      Time  Gimbal1 X          Y          Z      Roll    Pitch  \
# 0          1   0.00000  249.82106  187.58474  180.57219 -12.39070 -2.01555
# 1          2   0.00833  249.83210  187.59452  180.59978 -12.40695 -2.01875
# 2          3   0.01667  249.83810  187.59842  180.60562 -12.40569 -2.01162
# 3          4   0.02500  249.56720  187.36527  180.70454 -12.52173 -2.32281
# 4          5   0.03333  249.61419  187.39211  180.77912 -12.54384 -2.28618
# ...      ...       ...        ...        ...        ...       ...      ...
# 10864  10865  90.53333  397.87959  260.84824  180.46600 -14.74903 -1.47103
# 10865  10866  90.54167  397.87112  260.84820  180.42498 -14.71471 -1.48809
# 10866  10867  90.55000  397.85375  260.85878  180.41199 -14.71378 -1.49542
# 10867  10868  90.55833  397.87468  260.83202  180.54607 -14.75251 -1.51349
# 10868  10869  90.56667  397.92187  260.87020  180.47861 -14.74112 -1.45849
#
#            Yaw  Residual   Rot[0]  ...  Rot[0].2  Rot[1].2  Rot[2].2  \
# 0      0.33563   0.39052  0.99936  ...   1.00000   0.00000   0.00000
# 1      0.33568   0.37649  0.99936  ...   1.00000   0.00001   0.00165
# 2      0.35656   0.38759  0.99936  ...   1.00000   0.00016   0.00026
# 3      2.33896   0.31843  0.99835  ...   1.00000   0.00103   0.00072
# 4      2.32910   0.31691  0.99838  ...   1.00000   0.00093   0.00090
# ...        ...       ...      ...  ...       ...       ...       ...
# 10864 -0.24069   0.25802  0.99966  ...   0.99911  -0.04229   0.00080
# 10865 -0.28928   0.24027  0.99965  ...   0.99917  -0.04074   0.00225
# 10866 -0.25069   0.25937  0.99965  ...   0.99916  -0.04084   0.00214
# 10867 -0.26735   0.26083  0.99964  ...   0.99914  -0.04145   0.00218
# 10868 -0.26966   0.26220  0.99966  ...   0.99912  -0.04199   0.00183
#
#        Rot[3].2  Rot[4].2  Rot[5].2  Rot[6].2  Rot[7].2  Rot[8].2  Unnamed: 52
# 0       0.00000   1.00000  -0.00000  -0.00000  -0.00000   1.00000          NaN
# 1      -0.00001   1.00000  -0.00110  -0.00165   0.00110   1.00000          NaN
# 2      -0.00016   1.00000  -0.00019  -0.00026   0.00019   1.00000          NaN
# 3      -0.00103   0.99999   0.00405  -0.00072  -0.00405   0.99999          NaN
# 4      -0.00094   0.99999   0.00399  -0.00089  -0.00400   0.99999          NaN
# ...         ...       ...       ...       ...       ...       ...          ...
# 10864   0.04229   0.99910   0.00176  -0.00087  -0.00172   1.00000          NaN
# 10865   0.04075   0.99917  -0.00083  -0.00221   0.00092   1.00000          NaN
# 10866   0.04084   0.99917  -0.00060  -0.00211   0.00069   1.00000          NaN
# 10867   0.04145   0.99914   0.00026  -0.00219  -0.00017   1.00000          NaN
# 10868   0.04199   0.99912   0.00036  -0.00184  -0.00028   1.00000          NaN
#
# [10869 rows x 53 columns]

# %%
df.columns
# Out:
# Index(['Frame', 'Time', 'Gimbal1 X', 'Y', 'Z', 'Roll', 'Pitch', 'Yaw',
#        'Residual', 'Rot[0]', 'Rot[1]', 'Rot[2]', 'Rot[3]', 'Rot[4]', 'Rot[5]',
#        'Rot[6]', 'Rot[7]', 'Rot[8]', 'Unnamed: 18', 'Gimbal2 X', 'Y.1', 'Z.1',
#        'Roll.1', 'Pitch.1', 'Yaw.1', 'Residual.1', 'Rot[0].1', 'Rot[1].1',
#        'Rot[2].1', 'Rot[3].1', 'Rot[4].1', 'Rot[5].1', 'Rot[6].1', 'Rot[7].1',
#        'Rot[8].1', 'Unnamed: 35', 'M2 X', 'Y.2', 'Z.2', 'Roll.2', 'Pitch.2',
#        'Yaw.2', 'Residual.2', 'Rot[0].2', 'Rot[1].2', 'Rot[2].2', 'Rot[3].2',
#        'Rot[4].2', 'Rot[5].2', 'Rot[6].2', 'Rot[7].2', 'Rot[8].2',
#        'Unnamed: 52'],
#       dtype='object')

# %%
gimbal_pos = df[['Gimbal1 X','Y','Z']].to_numpy()
gimbal_rpy = df[['Roll','Pitch','Yaw']].to_numpy()
drone_pos = df[['M2 X','Y.2','Z.2']].to_numpy()
drone_rpy = df[['Roll.2','Pitch.2','Yaw.2']].to_numpy()

# %%
gimbal_pos[0]
# Out:
# array([249.82106, 187.58474, 180.57219])

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection = '3d')
# ax.plot(gimbal_pos[:,0], gimbal_pos[:,1], gimbal_pos[:,2], marker = '.')
ax.plot(gimbal_pos[:,0], gimbal_pos[:,1], gimbal_pos[:,2])
ax.plot(drone_pos[:,0], drone_pos[:,1], drone_pos[:,2])
plt.show()

# %%
fig, axs = plt.subplots(3,2, figsize=(12,8))

labels = ['x','y','z']
for i in range(3):
    axs[i,0].plot(drone_pos[:,i], label=f'drone-{labels[i]}')
    axs[i,0].plot(gimbal_pos[:,i], label=f'gimbal-{labels[i]}')
    axs[i,0].legend()

labels = ['roll', 'pitch', 'yaw']
for i in range(3):
    axs[i,1].plot(drone_rpy[:,i], label=f'drone-{labels[i]}')
    axs[i,1].plot(gimbal_rpy[:,i], label=f'gimbal-{labels[i]}')
    axs[i,1].legend()

plt.show()
